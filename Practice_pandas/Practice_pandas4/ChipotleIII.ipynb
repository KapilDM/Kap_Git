# %%
# Visualizing Chipotle's Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the 
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
grafica = chipo.groupby(["item_name"]).sum().sort_values("quantity",ascending = False)["quantity"].head(5).to_frame()
grafica

print(grafica["quantity"])

grafica
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
plt.bar(x=grafica.index.values, height=grafica.quantity)
plt.xticks(rotation='vertical')
plt.xlabel("Items")
plt.ylabel("Number of Times Ordered")
plt.title("Most Ordered Chipotle's Items")
plt.show()

# %%
#Create a Histogram of the top 5 items bought
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
var = chipo.groupby(["item_name"]).sum().sort_values("quantity",ascending=False)["quantity"].head().to_frame()
var
var["quantity"]
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
plt.bar(x = var.index, height =var["quantity"],width=0.4)

plt.title("Most ordered Chipotles Items")
plt.xlabel("Items")
plt.ylabel("Number of times ordered")

plt.xticks(rotation=90)


plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
def remove_dollar(x):
	return float(x[1:-1])

chipo["item_price"] = chipo["item_price"].apply(remove_dollar)


items_ord = chipo.groupby('order_id').sum()

plt.scatter(x = items_ord.item_price, y = items_ord.quantity, s = 50, c = 'green')

plt.title('Number of items ordered per order price')
plt.xlabel('Order Price')
plt.ylabel('Items ordered')

plt.show()

# %%
# Out:
# (0, 36.7178857951459)

# %% [markdown]
# ### BONUS: Create a question and a graph to answer your own question.
